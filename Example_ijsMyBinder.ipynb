// %%
console.log('running node within the project');
// Out:
// running node within the project

// %%
utils = require('jupyter-ijavascript-utils');
// Out:
// {
//   aggregate: {
//     property: [Function: propertyFromList],
//     deferCollection: [Function (anonymous)],
//     defer: [Function (anonymous)],
//     extent: [Function: extent],
//     min: [Function: min],
//     max: [Function: max],
//     sum: [Function: sum],
//     difference: [Function: difference],
//     avgMean: [Function: avgMean],
//     avgMedian: [Function: avgMedian],
//     first: [Function: first],
//     length: [Function: length],
//     unique: [Function: unique],
//     distinct: [Function: distinct],
//     countMap: [Function: countMap],
//     count: [Function: distribution],
//     duplicates: [Function: duplicates],
//     notIn: [Function: notIn],
//     isUnique: [Function: isUnique],
//     percentile: [Function: percentile],
//     percentile_01: [Function: percentile],
//     percentile_05: [Function: percentile],
//     percentile_10: [Function: percentile],
//     percentile_25: [Function: percentile],
// ...

// %%
utils.object.keys({ first: 'john', last: 'doe'});
// Out:
// [ 'first', 'last' ]
